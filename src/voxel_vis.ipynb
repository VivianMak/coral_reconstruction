# %%
from pyntcloud import PyntCloud
import numpy as np
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# Check downgrade numpy to np version: 1.26.4
print("np version:", np.__version__)
# Out:
# np version: 1.26.4

# %%
# PyntCloud library example

anky = PyntCloud.from_file("../data/ankylosaurus_mesh.ply")

# convert ply file to pcd with random samples from the surface
anky_cloud = anky.get_sample(
    "mesh_random", n=200000, rgb=True, normals=True, as_PyntCloud=True
)
print(anky_cloud)

# creating voxel grid from point cloud
voxelgrid_id = anky_cloud.add_structure("voxelgrid", n_x=64, n_y=64, n_z=64)
voxelgrid = anky_cloud.structures[voxelgrid_id]
voxelgrid.plot(d=3, mode="density", cmap="hsv")
# Out:
# PyntCloud
# 200000 points with 6 scalar fields
# 0 faces in mesh
# 0 kdtrees
# 0 voxelgrids
# Centroid: 0.014126911759376526, 1.12646484375, 2.8525633811950684
# Other attributes:
# Renderer(camera=PerspectiveCamera(aspect=1.6, fov=90.0, position=(27.899620056152344, 73.91397285461426, 104.5…

# %%
file = f"../data/bun00.pcd"
print(f"Looking at: {file}")

bunny_cloud = PyntCloud.from_file(file)
print(bunny_cloud)

voxelgrid_id = bunny_cloud.add_structure("voxelgrid", n_x=32, n_y=32, n_z=32)
voxelgrid = bunny_cloud.structures[voxelgrid_id]

voxelgrid.plot(d=3, mode="density")
# Out:
# Looking at: ../data/bun00.pcd
# PyntCloud
# 397 points with 4 scalar fields
# 0 faces in mesh
# 0 kdtrees
# 0 voxelgrids
# Centroid: -0.029080945998430252, 0.1026526615023613, 0.027301955968141556
# Other attributes:
# Renderer(camera=PerspectiveCamera(aspect=1.6, fov=90.0, position=(13.084210395812988, 44.518423080444336, 61.6…

# %%
# Try converting bunny ply to mesh

b = PyntCloud.from_file("../data/bunny_mesh.ply")

# convert ply file to pcd with random samples from the surface
b_cloud = b.get_sample(
    "mesh_random", n=200000, rgb=True, normals=True, as_PyntCloud=True
)
print(b_cloud)

# creating voxel grid from point cloud
voxelgrid_id = b_cloud.add_structure("voxelgrid", n_x=64, n_y=64, n_z=64)
voxelgrid = b_cloud.structures[voxelgrid_id]
voxelgrid.plot(d=3, mode="density", cmap="hsv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 4
#       1 b = PyntCloud.from_file("../data/bunny_mesh.ply")
#       3 # convert ply file to pcd with random samples from the surface
# ----> 4 b_cloud = b.get_sample(
#       5     "mesh_random", n=200000, rgb=True, normals=True, as_PyntCloud=True
#       6 )
#       7 print(b_cloud)
#       9 # creating voxel grid from point cloud
#
# File ~/coral_reconstruction/venv/lib/python3.10/site-packages/pyntcloud/core_class.py:533, in PyntCloud.get_sample(self, name, as_PyntCloud, **kwargs)
#     531 if name in ALL_SAMPLERS:
#     532     sampler = ALL_SAMPLERS[name](pyntcloud=self, **kwargs)
# --> 533     sampler.extract_info()
#     534     sample = sampler.compute()
#     536     if as_PyntCloud:
#
# ...
